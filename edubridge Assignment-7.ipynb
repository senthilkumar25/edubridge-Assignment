# %% [markdown]
# # Assignment-7

# %% [markdown]
# # Data Analysis Problem on Data Wrangling and Exploring

# %% [markdown]
# ### 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### 2. Import the dataset from this [address](https://raw.githubusercontent.com/svkarthik86/Advance-Python-Numpy/main/olympics_dirty.csv).

# %%
olympic_data=pd.read_csv("https://raw.githubusercontent.com/svkarthik86/Advance-Python-Numpy/main/olympics_dirty.csv",skiprows=4)
olympic_data
# Out:
#       Available_City  Edition_year Sport_name       Discipline  \
# 0             Athens          1896   Aquatics         Swimming
# 1             Athens          1896   Aquatics         Swimming
# 2             Athens          1896   Aquatics         Swimming
# 3             Athens          1896   Aquatics         Swimming
# 4             Athens          1896   Aquatics         Swimming
# ...              ...           ...        ...              ...
# 29211        Beijing          2008  Wrestling  Wrestling Gre-R
# 29212        Beijing          2008  Wrestling  Wrestling Gre-R
# 29213        Beijing          2008  Wrestling  Wrestling Gre-R
# 29214        Beijing          2008  Wrestling  Wrestling Gre-R
# 29215        Beijing          2008  Wrestling  Wrestling Gre-R
#
#                     Athlete  NOC Gender                       Event  \
# 0             HAJOS, Alfred  HUN    Men              100m freestyle
# 1          HERSCHMANN, Otto  AUT    Men              100m freestyle
# ...

# %% [markdown]
# ### 3. Assign it to a variable called odata.

# %%
odata=olympic_data

# %% [markdown]
# ### 4. show the first 5 entries

# %%
odata.head(5)
# Out:
#   Available_City  Edition_year Sport_name Discipline             Athlete  NOC  \
# 0         Athens          1896   Aquatics   Swimming       HAJOS, Alfred  HUN
# 1         Athens          1896   Aquatics   Swimming    HERSCHMANN, Otto  AUT
# 2         Athens          1896   Aquatics   Swimming   DRIVAS, Dimitrios  GRE
# 3         Athens          1896   Aquatics   Swimming  MALOKINIS, Ioannis  GRE
# 4         Athens          1896   Aquatics   Swimming  CHASAPIS, Spiridon  NaN
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M     NaN
# 4    Men  100m freestyle for sailors            M  Silver

# %% [markdown]
# ###  5. What is the number of observations in the dataset?

# %%
len(odata)
# Out:
# 29216

# %% [markdown]
# ### 6. What is the number of columns in the dataset?

# %%
len(odata.columns)
# Out:
# 10

# %% [markdown]
# ### 7. Print the name of all the columns.

# %%
print(odata.columns)
# Out:
# Index(['Available_City', 'Edition_year', 'Sport_name', 'Discipline', 'Athlete',
#        'NOC', 'Gender', 'Event', 'Event_gender', 'Medal'],
#       dtype='object')

# %% [markdown]
# ### 8. How is the dataset indexed?

# %%
odata.index
# Out:
# RangeIndex(start=0, stop=29216, step=1)

# %% [markdown]
# ### 9. Rename the column as  Available_City to City, Edition_year to Edition , Sport_name  to Sport

# %%
odata.rename(columns={"Available_City":"City","Edition_year":"Edition","Sport_name":"Sport"},inplace=True)
print(odata)
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ### 10. How many Athletes own the Gold medal?

# %%
len(odata.query("Medal=='Gold'"))
# Out:
# 9849

# %% [markdown]
# ### 11. Display the male gold medal winners for the 100m Track?

# %%
od1=odata[(odata.Medal=='Gold')&(odata.Gender=='Men')&(odata.Event=='100m')&(odata.Discipline=='Athletics')]
od1
# Out:
#                         City  Edition      Sport Discipline  \
# 13                    Athens     1896  Athletics  Athletics
# 231                    Paris     1900  Athletics  Athletics
# 737                 St Louis     1904  Athletics  Athletics
# 1191                  London     1908  Athletics  Athletics
# 2022               Stockholm     1912  Athletics  Athletics
# 2996                 Antwerp     1920  Athletics  Athletics
# 4236                   Paris     1924  Athletics  Athletics
# 5095               Amsterdam     1928  Athletics  Athletics
# 5806             Los Angeles     1932  Athletics  Athletics
# 6427                  Berlin     1936  Athletics  Athletics
# 7302                  London     1948  Athletics  Athletics
# 8121                Helsinki     1952  Athletics  Athletics
# 9009   Melbourne / Stockholm     1956  Athletics  Athletics
# 9924                    Rome     1960  Athletics  Athletics
# 10823                  Tokyo     1964  Athletics  Athletics
# ...

# %% [markdown]
# ### 12. Which three countries have won the most medals in recent years (from 1984 to 2008)?

# %%
odata[(odata.Edition>=1984)&(odata.Edition<=2008)]["NOC"].value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %% [markdown]
# ### 13. Which country has won the most men's gold medals in singles badminton over the years? Sort the results alphabetically by the player's  names.

# %%
print(odata.query("(Medal=='Gold')and(Gender=='Men')and(Event=='singles')and(Discipline=='Badminton')").NOC.value_counts()[:2])
odata.query("(Medal=='Gold')and(Gender=='Men')and(Event=='singles')and(Discipline=='Badminton')").sort_values("Athlete")
# Out:
# INA    2
# CHN    2
# Name: NOC, dtype: int64
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27741    Beijing     2008  Badminton  Badminton                 LIN, Dan  CHN
#
#       Gender    Event Event_gender Medal
# 20045    Men  singles            M  Gold
# 25734    Men  singles            M  Gold
# 21787    Men  singles            M  Gold
# 23717    Men  singles            M  Gold
# 27741    Men  singles            M  Gold

# %% [markdown]
# ### 14. Display the women gold medal winners for the 100m Track?

# %%
odata.query("(Medal=='Gold')&(Event=='100m')&(Gender=='Women')").Athlete.value_counts()
# Out:
# TYUS, Wyomia                 2
# DEVERS, Gail                 2
# STECHER, Renate              1
# BLANKERS-KOEN, Fanny         1
# RUDOLPH, Wilma               1
# KONDRATIEVA, Liudmila        1
# RICHTER-IRRGANG, Annegret    1
# NESTERENKO, Yuliya           1
# CUTHBERT, Betty              1
# JACKSON, Marjorie            1
# STEPHENS, Helen Herring      1
# ASHFORD, Evelyn              1
# ROBINSON, Elizabeth          1
# FRASER, Shelly-ann           1
# WALASIEWICZ, Stanislawa      1
# GRIFFITH-JOYNER, Florence    1
# Name: Athlete, dtype: int64

# %% [markdown]
# ### 15. list out the Sliver medal winner @ year 2008?

# %%
odata.query("(Edition==2008)and(Medal=='Silver')").sort_values(['Athlete'])
# Out:
#           City  Edition       Sport       Discipline             Athlete  NOC  \
# 27691  Beijing     2008   Athletics        Athletics    ABAKUMOVA, Maria  RUS
# 28921  Beijing     2008    Softball         Softball      ABBOTT, Monica  USA
# 29180  Beijing     2008   Wrestling  Wrestling Free.  ABDUSALOMOV, Yusup  TJK
# 27550  Beijing     2008   Athletics        Athletics  ABEYLEGESSE, Elvan  TUR
# 27652  Beijing     2008   Athletics        Athletics  ABEYLEGESSE, Elvan  TUR
# ...        ...      ...         ...              ...                 ...  ...
# 28585  Beijing     2008      Hockey           Hockey       ZHOU, Wanfeng  CHN
# 27394  Beijing     2008    Aquatics         Swimming        ZHU, Qianwei  CHN
# 28857  Beijing     2008    Shooting         Shooting          ZHU, Qinan  CHN
# 28396  Beijing     2008  Gymnastics      Rhythmic G.       ZHUKOVA, Inna  BLR
# 29172  Beijing     2008   Wrestling  Wrestling Free.     ZLATEVA, Stanka  BUL
#
# ...

# %% [markdown]
# ### 16.Group by Countries and apply aggregate function min,max,count  on over the year

# %%
odata.groupby("NOC")["Edition"].agg([min,max,len])
# Out:
#       min   max  len
# NOC
# AFG  2008  2008    1
# AHO  1988  1988    1
# ALG  1984  2008   14
# ANZ  1908  1912   29
# ARG  1924  2008  239
# ..    ...   ...  ...
# VIE  2000  2008    2
# YUG  1924  2000  435
# ZAM  1984  1996    2
# ZIM  1980  2008   23
# ZZX  1896  1904   48
#
# [138 rows x 3 columns]
